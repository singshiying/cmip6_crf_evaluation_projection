# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import os
import pandas as pd
import glob

# %%
sorted(list(filter(lambda x: '.nc' in x, os.listdir('/data04/shiy/temp_data/'))))
# Out:
# ['cl_Amon_ACCESS-CM2_historical_r1i1p1f1_gn_185001-186912.nc',
#  'cl_Amon_ACCESS-CM2_historical_r1i1p1f1_gn_187001-188912.nc',
#  'cl_Amon_ACCESS-CM2_historical_r1i1p1f1_gn_189001-190912.nc',
#  'cl_Amon_ACCESS-CM2_historical_r1i1p1f1_gn_191001-192912.nc',
#  'cl_Amon_ACCESS-CM2_historical_r1i1p1f1_gn_193001-194912.nc',
#  'cl_Amon_ACCESS-CM2_historical_r1i1p1f1_gn_195001-196912.nc',
#  'cl_Amon_ACCESS-CM2_historical_r1i1p1f1_gn_197001-198912.nc',
#  'cl_Amon_ACCESS-CM2_historical_r1i1p1f1_gn_199001-200912.nc',
#  'cl_Amon_ACCESS-CM2_historical_r1i1p1f1_gn_201001-201412.nc',
#  'cl_Amon_ACCESS-CM2_ssp245_r1i1p1f1_gn_201501-203412.nc',
#  'cl_Amon_ACCESS-CM2_ssp245_r1i1p1f1_gn_203501-205412.nc',
#  'cl_Amon_ACCESS-CM2_ssp245_r1i1p1f1_gn_205501-207412.nc',
#  'cl_Amon_ACCESS-CM2_ssp245_r1i1p1f1_gn_207501-209412.nc',
#  'cl_Amon_ACCESS-CM2_ssp245_r1i1p1f1_gn_209501-210012.nc',
#  'cl_Amon_ACCESS-CM2_ssp585_r1i1p1f1_gn_224101-226012.nc',
#  'cl_Amon_ACCESS-CM2_ssp585_r1i1p1f1_gn_226101-228012.nc',
#  'cl_Amon_ACCESS-CM2_ssp585_r1i1p1f1_gn_228101-230012.nc',
#  'cl_Amon_ACCESS-ESM1-5_historical_r1i1p1f1_gn_185001-186912.nc',
#  'cl_Amon_ACCESS-ESM1-5_historical_r1i1p1f1_gn_187001-188912.nc',
#  'cl_Amon_ACCESS-ESM1-5_historical_r1i1p1f1_gn_189001-190912.nc',
#  'cl_Amon_ACCESS-ESM1-5_historical_r1i1p1f1_gn_191001-192912.nc',
#  'cl_Amon_ACCESS-ESM1-5_historical_r1i1p1f1_gn_193001-194912.nc',
#  'cl_Amon_ACCESS-ESM1-5_historical_r1i1p1f1_gn_195001-196912.nc',
#  'cl_Amon_ACCESS-ESM1-5_historical_r1i1p1f1_gn_197001-198912.nc',
#  'cl_Amon_ACCESS-ESM1-5_historical_r1i1p1f1_gn_199001-200912.nc',
#  'cl_Amon_ACCESS-ESM1-5_historical_r1i1p1f1_gn_201001-201412.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_201501-203412.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_203501-205412.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_205501-207412.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_207501-209412.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp245_r1i1p1f1_gn_209501-210012.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_201501-203412.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_203501-205412.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_205501-207412.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_207501-209412.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_209501-210012.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_210101-212012.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_212101-214012.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_214101-216012.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_216101-218012.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_218101-220012.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_220101-222012.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_222101-224012.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_224101-226012.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_226101-228012.nc',
#  'cl_Amon_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_228101-230012.nc',
#  'cl_Amon_BCC-CSM2-MR_historical_r1i1p1f1_gn_185001-186412.nc',
#  'cl_Amon_BCC-CSM2-MR_historical_r1i1p1f1_gn_186501-187912.nc',
#  'cl_Amon_BCC-CSM2-MR_historical_r1i1p1f1_gn_188001-189412.nc',
#  'cl_Amon_BCC-CSM2-MR_historical_r1i1p1f1_gn_189501-190912.nc',
#  'cl_Amon_BCC-CSM2-MR_historical_r1i1p1f1_gn_191001-192412.nc',
#  'cl_Amon_BCC-CSM2-MR_historical_r1i1p1f1_gn_192501-193912.nc',
#  'cl_Amon_BCC-CSM2-MR_historical_r1i1p1f1_gn_194001-195412.nc',
#  'cl_Amon_BCC-CSM2-MR_historical_r1i1p1f1_gn_195501-196912.nc',
#  'cl_Amon_BCC-CSM2-MR_historical_r1i1p1f1_gn_197001-198412.nc',
#  'cl_Amon_BCC-CSM2-MR_historical_r1i1p1f1_gn_198501-199912.nc',
#  'cl_Amon_BCC-CSM2-MR_historical_r1i1p1f1_gn_200001-201412.nc',
#  'cl_Amon_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_201501-202912.nc',
#  'cl_Amon_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_203001-204412.nc',
#  'cl_Amon_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_204501-205912.nc',
#  'cl_Amon_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_206001-207412.nc',
#  'cl_Amon_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_207501-208912.nc',
#  'cl_Amon_BCC-CSM2-MR_ssp245_r1i1p1f1_gn_209001-210012.nc',
#  'cl_Amon_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_201501-202912.nc',
#  'cl_Amon_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_203001-204412.nc',
#  'cl_Amon_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_204501-205912.nc',
#  'cl_Amon_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_206001-207412.nc',
#  'cl_Amon_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_207501-208912.nc',
#  'cl_Amon_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_209001-210012.nc',
#  'cl_Amon_CAS-ESM2-0_ssp245_r1i1p1f1_gn_201501-206412.nc',
#  'cl_Amon_CAS-ESM2-0_ssp245_r1i1p1f1_gn_206501-210012.nc',
#  'cl_Amon_CAS-ESM2-0_ssp585_r1i1p1f1_gn_201501-206412.nc',
#  'cl_Amon_CAS-ESM2-0_ssp585_r1i1p1f1_gn_206501-210012.nc',
#  'cl_Amon_CESM2-WACCM_historical_r1i1p1f1_gn_185001-201412.nc',
#  'cl_Amon_CESM2-WACCM_ssp245_r1i1p1f1_gn_201501-206412.nc',
#  'cl_Amon_CESM2-WACCM_ssp245_r1i1p1f1_gn_206501-210012.nc',
#  'cl_Amon_CMCC-CM2-SR5_historical_r1i1p1f1_gn_185001-187412.nc',
#  'cl_Amon_CMCC-CM2-SR5_historical_r1i1p1f1_gn_187501-189912.nc',
#  'cl_Amon_CMCC-CM2-SR5_historical_r1i1p1f1_gn_190001-192412.nc',
#  'cl_Amon_CMCC-CM2-SR5_historical_r1i1p1f1_gn_192501-194912.nc',
#  'cl_Amon_CMCC-CM2-SR5_historical_r1i1p1f1_gn_195001-197412.nc',
#  'cl_Amon_CMCC-CM2-SR5_historical_r1i1p1f1_gn_197501-199912.nc',
#  'cl_Amon_CMCC-CM2-SR5_historical_r1i1p1f1_gn_200001-201412.nc',
#  'cl_Amon_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_201501-203912.nc',
#  'cl_Amon_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_204001-206412.nc',
#  'cl_Amon_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_206501-208912.nc',
#  'cl_Amon_CMCC-CM2-SR5_ssp245_r1i1p1f1_gn_209001-210012.nc',
#  'cl_Amon_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_201501-203912.nc',
#  'cl_Amon_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_204001-206412.nc',
#  'cl_Amon_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_206501-208912.nc',
#  'cl_Amon_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_209001-210012.nc',
#  'cl_Amon_CanESM5_historical_r1i1p1f1_gn_185001-201412.nc',
#  'cl_Amon_CanESM5_ssp245_r1i1p1f1_gn_201501-210012.nc',
#  'cl_Amon_CanESM5_ssp585_r1i1p1f1_gn_201501-210012.nc',
#  'cl_Amon_FGOALS-g3_ssp245_r1i1p1f1_gn_201501-201912.nc',
#  'cl_Amon_FGOALS-g3_ssp245_r1i1p1f1_gn_202001-202912.nc',
#  'cl_Amon_FGOALS-g3_ssp245_r1i1p1f1_gn_203001-203912.nc',
#  'cl_Amon_FGOALS-g3_ssp245_r1i1p1f1_gn_204001-204912.nc',
#  'cl_Amon_FGOALS-g3_ssp245_r1i1p1f1_gn_205001-205912.nc',
#  'cl_Amon_FGOALS-g3_ssp245_r1i1p1f1_gn_206001-206912.nc',
#  'cl_Amon_FGOALS-g3_ssp245_r1i1p1f1_gn_207001-207912.nc',
#  'cl_Amon_FGOALS-g3_ssp245_r1i1p1f1_gn_208001-208912.nc',
#  'cl_Amon_FGOALS-g3_ssp245_r1i1p1f1_gn_209001-209912.nc',
#  'cl_Amon_FGOALS-g3_ssp245_r1i1p1f1_gn_210001-210012.nc',
#  'cl_Amon_FGOALS-g3_ssp585_r1i1p1f1_gn_201501-201912.nc',
#  'cl_Amon_FGOALS-g3_ssp585_r1i1p1f1_gn_202001-202912.nc',
#  'cl_Amon_FGOALS-g3_ssp585_r1i1p1f1_gn_203001-203912.nc',
#  'cl_Amon_FGOALS-g3_ssp585_r1i1p1f1_gn_204001-204912.nc',
#  'cl_Amon_FGOALS-g3_ssp585_r1i1p1f1_gn_205001-205912.nc',
#  'cl_Amon_FGOALS-g3_ssp585_r1i1p1f1_gn_206001-206912.nc',
#  'cl_Amon_FGOALS-g3_ssp585_r1i1p1f1_gn_207001-207912.nc',
#  'cl_Amon_FGOALS-g3_ssp585_r1i1p1f1_gn_208001-208912.nc',
#  'cl_Amon_FGOALS-g3_ssp585_r1i1p1f1_gn_209001-209912.nc',
#  'cl_Amon_FGOALS-g3_ssp585_r1i1p1f1_gn_210001-210012.nc',
#  'cl_Amon_GFDL-ESM4_historical_r1i1p1f1_gr1_185001-194912.nc',
#  'cl_Amon_GFDL-ESM4_historical_r1i1p1f1_gr1_195001-201412.nc',
#  'cl_Amon_GFDL-ESM4_ssp245_r1i1p1f1_gr1_201501-210012.nc',
#  'cl_Amon_GFDL-ESM4_ssp585_r1i1p1f1_gr1_201501-210012.nc',
#  'cl_Amon_IPSL-CM6A-LR_historical_r1i1p1f1_gr_185001-201412.nc',
#  'cl_Amon_IPSL-CM6A-LR_ssp245_r1i1p1f1_gr_201501-210012.nc',
#  'cl_Amon_IPSL-CM6A-LR_ssp585_r1i1p1f1_gr_201501-210012.nc',
#  'cl_Amon_IPSL-CM6A-LR_ssp585_r1i1p1f1_gr_210101-230012.nc',
#  'cl_Amon_KACE-1-0-G_historical_r1i1p1f1_gr_185001-201412.nc',
#  'cl_Amon_KACE-1-0-G_ssp245_r1i1p1f1_gr_201501-210012.nc',
#  'cl_Amon_KACE-1-0-G_ssp585_r1i1p1f1_gr_201501-210012.nc',
#  'cl_Amon_MIROC6_historical_r1i1p1f1_gn_185001-185912.nc',
#  'cl_Amon_MIROC6_historical_r1i1p1f1_gn_186001-186912.nc',
#  'cl_Amon_MIROC6_historical_r1i1p1f1_gn_187001-187912.nc',
#  'cl_Amon_MIROC6_historical_r1i1p1f1_gn_188001-188912.nc',
#  'cl_Amon_MIROC6_historical_r1i1p1f1_gn_189001-189912.nc',
#  'cl_Amon_MIROC6_historical_r1i1p1f1_gn_190001-190912.nc',
#  'cl_Amon_MIROC6_historical_r1i1p1f1_gn_191001-191912.nc',
#  'cl_Amon_MIROC6_historical_r1i1p1f1_gn_192001-192912.nc',
#  'cl_Amon_MIROC6_historical_r1i1p1f1_gn_193001-193912.nc',
#  'cl_Amon_MIROC6_historical_r1i1p1f1_gn_194001-194912.nc',
#  'cl_Amon_MIROC6_historical_r1i1p1f1_gn_195001-195912.nc',
#  'cl_Amon_MIROC6_historical_r1i1p1f1_gn_196001-196912.nc',
#  'cl_Amon_MIROC6_historical_r1i1p1f1_gn_197001-197912.nc',
#  'cl_Amon_MIROC6_historical_r1i1p1f1_gn_198001-198912.nc',
#  'cl_Amon_MIROC6_historical_r1i1p1f1_gn_199001-199912.nc',
#  'cl_Amon_MIROC6_historical_r1i1p1f1_gn_200001-200912.nc',
#  'cl_Amon_MIROC6_historical_r1i1p1f1_gn_201001-201412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_185001-185412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_185501-185912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_186001-186412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_186501-186912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_187001-187412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_187501-187912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_188001-188412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_188501-188912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_189001-189412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_189501-189912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_190001-190412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_190501-190912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_191001-191412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_191501-191912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_192001-192412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_192501-192912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_193001-193412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_193501-193912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_194001-194412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_194501-194912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_195001-195412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_195501-195912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_196001-196412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_196501-196912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_197001-197412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_197501-197912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_198001-198412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_198501-198912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_199001-199412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_199501-199912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_200001-200412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_200501-200912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_201001-201412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_201501-201912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_202001-202412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_202501-202912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_203001-203412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_203501-203912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_204001-204412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_204501-204912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_205001-205412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_205501-205912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_206001-206412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_206501-206912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_207001-207412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_207501-207912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_208001-208412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_208501-208912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_209001-209412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_209501-209912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp245_r1i1p1f1_gn_210001-210012.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_201501-201912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_202001-202412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_202501-202912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_203001-203412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_203501-203912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_204001-204412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_204501-204912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_205001-205412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_205501-205912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_206001-206412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_206501-206912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_207001-207412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_207501-207912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_208001-208412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_208501-208912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_209001-209412.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_209501-209912.nc',
#  'cl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_210001-210012.nc',
#  'cl_Amon_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_185001-186912.nc',
#  'cl_Amon_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_187001-188912.nc',
#  'cl_Amon_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_189001-190912.nc',
#  'cl_Amon_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_191001-192912.nc',
#  'cl_Amon_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_193001-194912.nc',
#  'cl_Amon_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_195001-196912.nc',
#  'cl_Amon_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_197001-198912.nc',
#  'cl_Amon_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_199001-200912.nc',
#  'cl_Amon_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_201001-201412.nc',
#  'cl_Amon_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_201501-203412.nc',
#  'cl_Amon_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_203501-205412.nc',
#  'cl_Amon_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_205501-207412.nc',
#  'cl_Amon_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_207501-209412.nc',
#  'cl_Amon_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_209501-210012.nc',
#  'cl_Amon_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_201501-203412.nc',
#  'cl_Amon_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_203501-205412.nc',
#  'cl_Amon_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_205501-207412.nc',
#  'cl_Amon_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_207501-209412.nc',
#  'cl_Amon_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_209501-210012.nc',
#  'cl_Amon_NESM3_historical_r1i1p1f1_gn_185001-201412.nc',
#  'cl_Amon_NESM3_ssp245_r1i1p1f1_gn_201501-210012.nc',
#  'cl_Amon_NESM3_ssp585_r1i1p1f1_gn_201501-210012.nc']

# %%
models=['ACCESS-CM2','ACCESS-ESM1-5','BCC-CSM2-MR','CAS-ESM2-0','CMCC-CM2-SR5','CanESM5','FGOALS-g3','GFDL-ESM4','IPSL-CM6A-LR','KACE-1-0-G','MPI-ESM1-2-HR','MPI-ESM1-2-LR','NESM3']
#13个模式

# %%
xr.open_dataset(matched_files[0])
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 240, bnds: 2, lev: 85, lat: 144, lon: 192)
# Coordinates:
#   * time       (time) datetime64[ns] 2015-01-16T12:00:00 ... 2034-12-16T12:00:00
#   * lev        (lev) float64 20.0 53.33 100.0 ... 7.378e+04 7.91e+04 8.5e+04
#   * lat        (lat) float64 -89.38 -88.12 -86.88 -85.62 ... 86.88 88.12 89.38
#   * lon        (lon) float64 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] ...
#     lev_bnds   (lev, bnds) float64 ...
#     b          (lev) float64 ...
#     orog       (lat, lon) float32 ...
#     b_bnds     (lev, bnds) float64 ...
#     lat_bnds   (lat, bnds) float64 ...
#     lon_bnds   (lon, bnds) float64 ...
#     cl         (time, lev, lat, lon) float32 ...
# Attributes: (12/47)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            ScenarioMIP
#     branch_method:          standard
#     branch_time_in_child:   60265.0
#     branch_time_in_parent:  60265.0
#     creation_date:          2019-11-08T05:30:07Z
#     ...                     ...
#     variable_id:            cl
#     variant_label:          r1i1p1f1
#     version:                v20191108
#     cmor_version:           3.4.0
#     tracking_id:            hdl:21.14100/74918ae3-993c-4099-9c89-eb43374194f7
#     license:                CMIP6 model data produced by CSIRO is licensed un...

# %%
def cal_cl2llc(ds):
    #ds为timexlevxlatxlon的云量数据
    low_cloud = ds.sel(lev=ds.lev >= 700)  # 选择低云层次
    low_cloud_cover = low_cloud.max(dim="lev")     
    return low_cloud_cover

# %%
olat=np.arange(-89.5,90,1)
olon=np.arange(0.5,360,1)
weights = np.cos(np.deg2rad(olat))
for m in range(len(models))[0:1]:
    print(models[m])
    matched_files = glob.glob(os.path.join('/data04/shiy/temp_data/', f'*{models[m]}_ssp245*'))
    if len(matched_files)>1:
        ds = xr.open_mfdataset(matched_files,combine='by_coords',parallel=True,chunks={"time": 100})
        llc = cal_cl2llc(ds).interp(lon=olon,lat=olat,method='linear',kwargs={'fill_value': 'extrapolate'})
    else:
        ds = xr.open_dataset(matched_files[0])
        llc = cal_cl2llc(ds).interp(lon=olon,lat=olat,method='linear',kwargs={'fill_value': 'extrapolate'})
print(llc)
# Out:
# ACCESS-CM2
# <xarray.Dataset>
# Dimensions:    (time: 1032, bnds: 2, lat: 180, lon: 360)
# Coordinates:
#   * time       (time) datetime64[ns] 2015-01-16T12:00:00 ... 2100-12-16T12:00:00
#   * lon        (lon) float64 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
#   * lat        (lat) float64 -89.5 -88.5 -87.5 -86.5 ... 86.5 87.5 88.5 89.5
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] dask.array<chunksize=(100, 2), meta=np.ndarray>
#     lev_bnds   (time, bnds) float64 dask.array<chunksize=(240, 2), meta=np.ndarray>
#     b          (time) float64 dask.array<chunksize=(240,), meta=np.ndarray>
#     orog       (time, lat, lon) float32 dask.array<chunksize=(240, 180, 360), meta=np.ndarray>
#     b_bnds     (time, bnds) float64 dask.array<chunksize=(240, 2), meta=np.ndarray>
#     lat_bnds   (time, lat, bnds) float64 dask.array<chunksize=(240, 180, 2), meta=np.ndarray>
#     lon_bnds   (time, lon, bnds) float64 dask.array<chunksize=(240, 360, 2), meta=np.ndarray>
#     cl         (time, lat, lon) float32 dask.array<chunksize=(100, 180, 360), meta=np.ndarray>
# /data04/shiy/anaconda3/envs/climlib/lib/python3.8/site-packages/xarray/core/indexing.py:1379: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
